# %% [markdown]
# # Unit 4 Assessment 5 - Deep Learning Training Project
#
# Rob Johnston - TQUK Level 3 Certificate in AI Programming with Python
#
# Criteria covered: 3.1 Iris and synthetic training, 3.2 Iris validation tuning, 3.3 Iris inference

# %% [markdown]
# ## Run the project script
# This regenerates the checkpoint, metrics, summary JSON and evidence images.

# %%
# %run assessment5_train_validate_infer.py

# %% [markdown]
# ## Generated evidence images

# %% [markdown]
# ![assessment5_iris_training_loss](outputs/assessment5_iris_training_loss.png)

# %% [markdown]
# ![assessment5_synthetic_training_loss](outputs/assessment5_synthetic_training_loss.png)

# %% [markdown]
# ![assessment5_iris_validation_tuning_summary](outputs/assessment5_iris_validation_tuning_summary.png)

# %% [markdown]
# ![assessment5_iris_test_confusion_matrix](outputs/assessment5_iris_test_confusion_matrix.png)

# %% [markdown]
# ![assessment5_iris_inference_result](outputs/assessment5_iris_inference_result.png)

# %% [markdown]
# ## Summary JSON

# %%
import json
summary = json.load(open(r'outputs/assessment5_summary.json', encoding='utf-8'))
summary
