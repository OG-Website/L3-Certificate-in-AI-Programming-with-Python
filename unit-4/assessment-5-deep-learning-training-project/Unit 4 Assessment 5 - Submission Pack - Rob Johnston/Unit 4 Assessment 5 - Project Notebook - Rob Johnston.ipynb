# %% [markdown]
# # Unit 4 Assessment 5 - Deep Learning Training Project
#
# ![Trade-A-Them logo](assets/TradeAThemLogo.png)
#
# Rob Johnston - TQUK Level 3 Certificate in AI Programming with Python
#
# Project context: Trade-A-Them active cryptocurrency trading-bot project. The Iris dataset is used as a controlled baseline, and the Trade-A-Them-style synthetic cryptocurrency signal dataset is used as a safe trading-bot style classification example.
#
# Criteria covered: 3.1 two ways to train a deep learning model, 3.2 validation-set hyperparameter tuning, and 3.3 inference.

# %% [markdown]
# ## Run the project script
# This regenerates the checkpoints, metrics, summary JSON and evidence images.

# %%
# %run assessment5_train_validate_infer.py

# %% [markdown]
# ## Evidence images

# %% [markdown]
# ### Iris baseline training loss
# ![Iris baseline training loss](outputs/assessment5_iris_training_loss.png)

# %% [markdown]
# ### Trade-A-Them-style synthetic crypto signal training loss
# ![Trade-A-Them-style synthetic crypto signal training loss](outputs/assessment5_tradeathem_synthetic_crypto_training_loss.png)

# %% [markdown]
# ### Iris validation tuning summary
# ![Iris validation tuning summary](outputs/assessment5_iris_validation_tuning_summary.png)

# %% [markdown]
# ### Iris test confusion matrix
# ![Iris test confusion matrix](outputs/assessment5_iris_test_confusion_matrix.png)

# %% [markdown]
# ### Iris inference result
# ![Iris inference result](outputs/assessment5_iris_inference_result.png)

# %% [markdown]
# ## Summary JSON

# %%
import json
summary = json.load(open('outputs/assessment5_summary.json', encoding='utf-8'))
summary
