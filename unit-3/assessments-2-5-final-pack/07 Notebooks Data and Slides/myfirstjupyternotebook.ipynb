# %% [markdown]
# ### This is my first Jupyter Notebook
# * The code will output a string **Hello, AI World**
# *And output the contents of two variables added together*

# %%
print("Hello, AI World")
# Out:
# Hello, AI World

# %%
a= 10
b= 20

# %%
print(a + b)
# Out:
# 30
